# %%
import pandas as pd

# %%
from email import feedparser
dados = {
    'nome': ['João','Maria','Jose','Pedro'],
    'idade': [12,13,14,15],
    'salario':[1000,2000,3000,4000]

}
print(dados)
# Out:
# {'nome': ['João', 'Maria', 'Jose', 'Pedro'], 'idade': [12, 13, 14, 15], 'salario': [1000, 2000, 3000, 4000]}
